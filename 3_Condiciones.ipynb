# %% [markdown]
# <a href="https://colab.research.google.com/github/NormandoRamirezDelgado/3A-IAM-2026/blob/main/3_Condiciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estructuras de Condición IF
#
# ## Estructura de Condición Simple
#
# ### Sintaxis.
#
# ### if (variable operador variable):
# ### &emsp;&emsp;&emsp;&emsp;Opción verdadera
# ### &emsp;&emsp;&emsp;&emsp;instrucción(es)
#
# ### Los operadores son: >, <, >=, <=, ==, !=

# %%
# Ejemplo de Condición Simple

edad = 28

if edad >= 18:
  print("1 Eres mayor de edad")
print("2 Eres mayor de edad")
# Out:
# 1 Eres mayor de edad
# 2 Eres mayor de edad
# 3 Eres mayor de edad
# 4 Eres mayor de edad
# 5 Eres mayor de edad
# 6 Eres mayor de edad

# %%
# Ejemplo de Condición Doble

edad = 18

if edad >= 18:
  print('Eres Mayor de Edad')
else:
  print('Eres Menor de Edad')
# Out:
# Eres Menor de Edad

# %%
# Ejemplo de Condición Anidada

numeroUno = 10
numeroDos = 20
numeroTres = 30

if numeroUno
