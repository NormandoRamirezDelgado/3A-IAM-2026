# %% [markdown]
# <a href="https://colab.research.google.com/github/NormandoRamirezDelgado/3A-IAM-2026/blob/main/Practica1P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Hacer un programa que pida el nombre completo y grupo y semestre en variables de manera separada.
# Imprimir como salida "Soy nombre del grupo grupo°Letra"
nombre = 'Normando Alán Ramírez Delgado'
grupo = '3A-IAM'
print(nombre)
print(grupo)
print(f'Soy {nombre} del grupo {grupo}')
# Out:
# Normando Alán Ramírez Delgado
# 3A-IAM
# Soy Normando Alán Ramírez Delgado del grupo 3A-IAM
